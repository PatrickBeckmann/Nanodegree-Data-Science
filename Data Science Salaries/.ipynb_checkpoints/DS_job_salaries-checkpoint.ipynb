# %% [markdown]
# # Analyzing Data Science Job Salaries

# %%
#Data
import numpy as np
import pandas as pd

#Visualisation
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import squarify

pd.set_option('display.max_columns',None)

df = pd.read_csv('./ds_salaries.csv')
#Dataset from: https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ### 1st Question

# %% [markdown]
# ### 2nd Question

# %% [markdown]
# ### 3rd Question

# %% [markdown]
# ### Description of Columns

# %% [markdown]
# **work_year:** The year the salary was paid.<br>
# **experience_level:** The experience level in the job during the year with the following possible values: **EN** Entry-level / Junior **MI** Mid-level / Intermediate **SE** Senior-level / Expert **EX** Executive-level / Director<br>
# **employment_type:** The type of employement for the role: **PT** Part-time **FT** Full-time **CT** Contract **FL** Freelance<br>
# **salary:** The total gross salary amount paid.<br>
# **salary_currency:** The currency of the salary paid as an ISO 4217 currency code.<br>
# **salary_in_usd:** The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com).<br>
# **employee_residence:** Employee's primary country of residence in during the work year as an ISO 3166 country code.<br>
# **remote_ratio:** The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)<br>
# **company_location:** The country of the employer's main office or contracting branch as an ISO 3166 country code.<br>
# **company_size:** The average number of people that worked for the company during the year: **S** less than 50 employees (small) **M** 50 to 250 employees (medium) **L** more than 250 employees (large)

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# Great for Data Understanding/ Analysis: https://www.kaggle.com/code/varunsaikanuri/data-science-job-salaries-eda / https://www.kaggle.com/code/wonduk/eda-on-data-science-job-salaries
# Interactive Map: https://www.kaggle.com/code/priyark/data-science-job-salaries-plotly-interactive-graph/notebook

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Drop the Column unnamed, because it does not carry any useful
df=df.drop('Unnamed: 0',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count   607.000000  6.070000e+02     607.000000     607.00000
# mean   2021.405272  3.240001e+05  112297.869852      70.92257
# std       0.692133  1.544357e+06   70957.259411      40.70913
# min    2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000
# max    2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.corr()
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.087577       0.170493      0.076314
# salary         -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd   0.170493 -0.083906       1.000000      0.132122
# remote_ratio    0.076314 -0.014608       0.132122      1.000000

# %%
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)

# %%
"""pd.set_option('display.max_rows', None)
cat_cols = df.select_dtypes(include=object).columns.tolist()
(pd.DataFrame(
    df[cat_cols]
    .melt(var_name='column', value_name='value')
    .value_counts())
.rename(columns={0: 'counts'})
.sort_values(by=['column', 'counts'], ascending = False))"""
# Out:
# "pd.set_option('display.max_rows', None)\ncat_cols = df.select_dtypes(include=object).columns.tolist()\n(pd.DataFrame(\n    df[cat_cols]\n    .melt(var_name='column', value_name='value')\n    .value_counts())\n.rename(columns={0: 'counts'})\n.sort_values(by=['column', 'counts'], ascending = False))"

# %%
ex_level = df['experience_level'].value_counts()
label = df['experience_level'].value_counts().index
color=sns.color_palette("pastel", len(ex_level))
squarify.plot(sizes = ex_level, color = color, label = label)
plt.show()

# %%
df['experience_level'].value_counts(normalize=True)
# Out:
# SE    0.461285
# MI    0.350906
# EN    0.144975
# EX    0.042834
# Name: experience_level, dtype: float64

# %%
job_title = df['job_title'].value_counts().nlargest(10).index
count = df['job_title'].value_counts().nlargest(10)
plt.figure(figsize=(15, 8))
plt.bar(job_title, count, color = sns.color_palette("pastel", len(job_title)))

plt.title("Top 10 Job Titles")
plt.xticks(rotation=45, ha='right', fontsize = 16)

plt.show()

# %% [markdown]
# ## Count of number of people with all experience levels in each job

# %%
job_title = df['job_title'].value_counts().index
count = df.groupby('job_title')['experience_level'].value_counts().unstack()
count.plot(kind='bar', stacked= True, figsize= (20,8), color = sns.color_palette("pastel"))

plt.title("Experience Level for Top 10 Titles")
plt.xticks(rotation=45, ha='right', fontsize = 16)

plt.show()

# %% [markdown]
# ## Employment Type

# %% [markdown]
# ## Type of work (Remote, On Premise, Hybrid)

# %% [markdown]
# ## Company vs. Employee Residence

# %% [markdown]
# ## Experience Level vs. Salary (Interactive)

# %% [markdown]
# ## Data Preparartion

# %% [markdown]
# Converting Columns with type `object`

# %%
ordinal_cols_mapping = {'EN': 1, 'MI': 2, 'SE': 3, 'EX': 4}

# %%
df['experience_level_code'] = df['experience_level'].replace(ordinal_cols_mapping)
df['experience_level_code'].head()

# %%
#df_encoded = pd.get_dummies(df, columns=['employment_type', 'salary_currency', 'employee_residence', 'company_location', 'company_size'])

# %%
#pd.set_option('display.max_rows', 10)
#print(df_encoded)

# %%
#pd.set_option('display.max_rows', None)
#print(df_encoded.corr()['salary'])

# %%
#sns.heatmap(df_encoded.corr(), annot=True, fmt=".2f");

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ## Results

# %%
#https://www.kaggle.com/code/priyark/data-science-job-salaries-plotly-interactive-graph
